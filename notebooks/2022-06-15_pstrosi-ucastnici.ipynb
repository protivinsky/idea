# %%
import pandas as pd

# %%
df = pd.read_excel('/mnt/d/instruktor/Akce/2022-07-30 Nebuď pštros/ucastnici/medailonky.xlsx')

# %%
df = df[['Jméno finální', 'Fotka', 'Nejsem pštros...']].copy()

# %%
df.head()
# Out:
#   Jméno finální   Fotka                                   Nejsem pštros...
# 0         Domča   domca  Mám ptačí příjmení takže bych v tom v tom vidě...
# 1         Marky   marky  ...jsem lvice😀 - jsem celkem vůdčí osobnost a ...
# 2       Vašek H  vasekh  ale medvěd. Stejně jako medvěd se rád vyskytuj...
# 3        Halina  halina  Nejsem pštros, protože jsem vlk. Vlci byli ode...
# 4         Filip   filip  jsem vlk, která občas musí podnikat dlouhou po...

# %%
df = df.sort_values('Jméno finální')

# %%
for _, row in df.iterrows():
    name = row['Jméno finální']
    photo = row['Fotka']
    pstros = row['Nejsem pštros...']
    
    print(f"""
                    <div class="col-lg-4 col-md-6 col-sm-12 col-xs-12 d-flex align-items-stretch mt-4" data-aos="zoom-in" data-aos-delay="300">
                        <div class="card">
                            <img class="card-img-top" src="img/ucastnici/{photo}.jpg">
                            <div class="card-body">
                                <h4>{name}</h4>
                                <p>{pstros}</p>                    
                            </div>
                        </div>                        
                    </div>                    
    """)
# Out:
#                     <div class="col-lg-4 col-md-6 col-sm-12 col-xs-12 d-flex align-items-stretch mt-4" data-aos="zoom-in" data-aos-delay="300">
#                         <div class="card">
#                             <img class="card-img-top" src="img/ucastnici/anicka.jpg">
#                             <div class="card-body">
#                                 <h4>Anička</h4>
#                                 <p>Protože jsem včela. Ráda tvořím a pracuji se sladkým. Stejně jak včela mám ráda společnost milých přátel nebo rodiny.</p>
#                             </div>
#                         </div>
#                     </div>
#
#
#                     <div class="col-lg-4 col-md-6 col-sm-12 col-xs-12 d-flex align-items-stretch mt-4" data-aos="zoom-in" data-aos-delay="300">
#                         <div class="card">
#                             <img class="card-img-top" src="img/ucastnici/dominik.jpg">
#                             <div class="card-body">
# ...
