# %% [markdown]
# # PISA 2015

# %%
.libPaths('rlib')

# %%
library(EdSurvey)
library(dplyr)
# Out:
# Loading required package: car
#
# Loading required package: carData
#
# Loading required package: lfactors
#
# lfactors v1.0.4
#
#
# EdSurvey v2.7.1
#
#
#
# Attaching package: ‘EdSurvey’
#
#
# The following objects are masked from ‘package:base’:
#
#     cbind, rbind
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:car’:
#
#     recode
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
downloadPISA('temp', years=2015, verbose=TRUE)
# Out:
# Processing PISA data for year 2015
# Database INT
# Unzipping 2015 PISA (INT database) files from temp/PISA//2015/PUF_SPSS_COMBINED_CMB_SCH_QQQ.zip
#  unzipping CY6_MS_CMB_SCH_QQQ.sav
# Unzipping 2015 PISA (INT database) files from temp/PISA//2015/PUF_SPSS_COMBINED_CMB_STU_COG.zip
#  unzipping CY6_MS_CMB_STU_COG.sav
# Unzipping 2015 PISA (INT database) files from temp/PISA//2015/PUF_SPSS_COMBINED_CMB_STU_CPS.zip
#  unzipping CY6_MS_CMB_STU_CPS.sav
# Unzipping 2015 PISA (INT database) files from temp/PISA//2015/PUF_SPSS_COMBINED_CMB_STU_FLT.zip
#  unzipping CY6_MS_CMB_FLT_TTM.sav
#  unzipping CY6_MS_CMB_STU_FLT.sav
#  unzipping ReadMe.txt
# Unzipping 2015 PISA (INT database) files from temp/PISA//2015/PUF_SPSS_COMBINED_CMB_STU_QQQ.zip
#  unzipping To Read.txt
#  unzipping CY6_MS_CMB_STU_QQ2.sav
#  unzipping CY6_MS_CMB_STU_QQQ.sav
# Unzipping 2015 PISA (INT database) files from temp/PISA//2015/PUF_SPSS_COMBINED_CMB_STU_QTM.zip
#  unzipping CY6_MS_CMB_STU_QTM.sav

# %%
cze15 <- readPISA('temp/PISA/2015', countries='cze')
# Out:
# Cache corrupt. Reprocessing PISA files
# Warning message:
# “'memory.limit()' is Windows-specific”
# Importing SAV data into R
# Processing ‘CY6_MS_CMB_STU_QQQ.sav’
# Processing ‘CY6_MS_CMB_STU_QQ2.sav’
# Processing ‘CY6_MS_CMB_STU_COG.sav’
# Processing ‘CY6_MS_CMB_STU_QTM.sav’
# Processing ‘CY6_MS_CMB_STU_FLT.sav’
# Processing ‘CY6_MS_CMB_STU_CPS.sav’
# Processing ‘CY6_MS_CMB_SCH_QQQ.sav’
# Importing ‘CY6_MS_CMB_STU_QQQ.sav’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_ALB.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_DZA.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_AUS.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_AUT.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_BEL.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_BRA.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_BGR.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_CAN.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_CHL.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_TAP.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_COL.rds’
#   saving tmp ‘CY6_MS_CMB_STU_QQQ_CRI.rds’
# ...
